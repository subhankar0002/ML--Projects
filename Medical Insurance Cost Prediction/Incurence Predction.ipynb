# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('insurance.csv')

# %%
# Out:
#    age  sex     bmi  children      charges  smoker_yes  region_northwest  \
# 0   19    0  27.900         0  16884.92400           1                 0
# 1   18    1  33.770         1   1725.55230           0                 0
# 2   28    1  33.000         3   4449.46200           0                 0
# 3   33    1  22.705         0  21984.47061           0                 1
# 4   32    1  28.880         0   3866.85520           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %% [markdown]
# **change data string to int**

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df['region_southwest']=label.fit_transform(df['region_southwest'])

# %% [markdown]
# **Change charges col position**

# %%
col=[i for i in df.columns if i!= 'charges']+['charges']
df=df[col]

# %% [markdown]
# **Find Outliers**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax=plt.subplots(figsize=(15,15))
sns.boxplot(data=x_train_sceal,ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# **data divition**

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %% [markdown]
# **split data into train & test**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

# %% [markdown]
# **Sealing**

# %%
'''from sklearn.preprocessing import RobustScaler
sceal=RobustScaler()
x_train_sceal=sceal.fit_transform(x_train)
x_test_sceal=sceal.transform(x_test)'''

# %% [markdown]
# **Model train**

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Acurrcy**

# %%
from sklearn.metrics import r2_score
y_pred=regression.predict(x_test)
r2=r2_score(y_test,y_pred)
print("R² Score (with RobustScaler):", r2)
# Out:
# R² Score (with RobustScaler): 0.7959688488543414

# %%
import pickle
pickle.dump(model, open('Insurence_Prediction.pkl', 'wb'))

# %%
# Out:
# R² Score (with RobustScaler): 0.7959688488543414
